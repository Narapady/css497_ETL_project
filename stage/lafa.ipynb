# %%
# import sys
# sys.path.append("../")
import os
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loss-adjusted Food Availability

# %%
def get_paths(dirname: str) -> list[str]:
    all_files = os.listdir(dirname)
    return [f"{dirname}{filename}" for filename in all_files]

def has_numbers(input_str: str) -> bool:
    if input_str.startswith("19") or input_str.startswith("20"):
        return True
    return False

def change_nan_col(df: pd.DataFrame) -> list[str]:
    cols = list(df.columns)
    indx = [i for i, col in enumerate(cols) if col is np.nan]

    if len(indx) == 2:
        new_cols = ["Loss oz/day", "Loss g/day"]
    elif len(indx) == 3:
        new_cols = ["Loss gal/year", "Loss oz/day", "Loss g/day"]
    elif len(indx) == 4:
        new_cols = ["Edible weight", "Other loss", "Loss oz/day", "Loss g/day"]
    elif len(indx) == 5:
        new_cols = ["Edible weight", "Other loss", "Loss gal/year", "Loss oz/day", "Loss g/day"]
    for i, col in zip(indx, new_cols):
        cols[i] = col
        
    return cols

def change_col_names(df: pd.DataFrame) -> dict[str, str]:
    avail_cal = ""
    primary_weight = ""
    for col in list(df.columns):
        if str(col).startswith("Calories"):
            avail_cal = col 
    for col in list(df.columns):
        if str(col).startswith("Primary"):
            primary_weight = col 
            
    new_col_names = {
        "Year": "year",
        primary_weight: "original weight",
        "Edible weight": "edible weight",
        "Total loss, all levels": "total percent loss",
        "Per capita availability adjusted for loss": "loss lbs/year",
        "Loss g/day": "loss g/day",
        avail_cal: "available calories/day"
        
    }
    
    return new_col_names

# %%
os.system(f"rm -rf {new_dir}")
# Out:
# 0

# %%
dirname = "Loss-Adjusted Food Availability/"
new_dir = dirname.lower().replace(" ", "-")[:-1] + "-clean"
os.mkdir(new_dir)

# %% [markdown]
# ### Total & percentage of calories available per capita

# %%
path = "./Loss-Adjusted Food Availability/calories.xls"
for sheet in range(1,3):
    df = pd.read_excel("./Loss-Adjusted Food Availability/calories.xls", sheet_name=sheet)
    sheetnames = pd.ExcelFile("./Loss-Adjusted Food Availability/calories.xls").sheet_names 
    df.columns = df.iloc[0]
    if sheet == 1:
        last_index = df[df['Year'] == 2017].index[0] + 1
    elif sheet == 2:
        last_index = df[df['Year'] == 2010].index[0] + 1
        
    df = df[4: last_index]
    df.reset_index(drop=True, inplace=True)
    index = df.loc[df["Year"] == "2000*"].index[0]
    df.loc[index:index+1,"Year"] = "2000"
    df.to_csv(f"{new_dir}/{sheetnames[sheet]}.csv", index=False)

# %%
get_paths(dirname)
# Out:
# ['Loss-Adjusted Food Availability/meat.xls',
#  'Loss-Adjusted Food Availability/sugar.xls',
#  'Loss-Adjusted Food Availability/Dairy.xls',
#  'Loss-Adjusted Food Availability/servings.xls',
#  'Loss-Adjusted Food Availability/fat.xls',
#  'Loss-Adjusted Food Availability/veg.xls',
#  'Loss-Adjusted Food Availability/Fruit.xls',
#  'Loss-Adjusted Food Availability/grain.xls',
#  'Loss-Adjusted Food Availability/calories.xls']

# %% [markdown]
# ### How much loss during the processing of each food group, per capita.

# %%
# each file
path_names = get_paths(dirname)
for path in path_names:
    if "calories" in path or "serving" in path:
        continue
    # get sheets to process
    file = pd.ExcelFile(path)
    sheet_names = file.sheet_names[1:]
    
    sub_dir = path[path.rfind("/") + 1: path.rfind(".")].lower()
    dir_path = os.path.join(new_dir, sub_dir)
    print(dir_path)

    try:
        os.mkdir(dir_path)
    except OSError as e:
        print(e)

    # each sheet
    for name in sheet_names:
        # read each sheet in the file
        print(f"- {name}")
        df = pd.read_excel(path, sheet_name=name)
        # use title as key 
        # title is header of each sheet
        filename = df.columns[0].split(":")[0].lower()
        filename = filename.replace(" ", "-").replace("/", "-")

        df.columns = df.iloc[0]
        filters = df['Year'].apply(lambda x: has_numbers(str(x)))
        df = df[filters]               
        
            
        df.columns = change_nan_col(df)
        new_col_names = change_col_names(df)
        df = df.rename(columns=new_col_names)
            
        final_cols = ["year", "original weight", "edible weight", "total percent loss", "loss lbs/year", "loss g/day", "available calories/day"]
        
        # total grains has no edible weight column 
        if name == 'Total grains':
            final_cols.remove("edible weight")
        df = df[final_cols]
        print(f"{dir_path}/{filename}.csv")
        df.to_csv(f"{dir_path}/{filename}.csv", index=False)
# Out:
# loss-adjusted-food-availability-clean/meat
# - Beef
# loss-adjusted-food-availability-clean/meat/beef.csv
# - Veal
# loss-adjusted-food-availability-clean/meat/veal.csv
# - Pork
# loss-adjusted-food-availability-clean/meat/pork.csv
# - Lamb
# loss-adjusted-food-availability-clean/meat/lamb.csv
# - Red meat
# loss-adjusted-food-availability-clean/meat/red-meat.csv
# - Chicken
# loss-adjusted-food-availability-clean/meat/chicken.csv
# - Turkey
# loss-adjusted-food-availability-clean/meat/turkey.csv
# - Poultry
# loss-adjusted-food-availability-clean/meat/poultry.csv
# - Fresh and frozen fish
# loss-adjusted-food-availability-clean/meat/fresh-and-frozen-fish.csv
# - Fresh and frozen shellfish
# loss-adjusted-food-availability-clean/meat/fresh-and-frozen-shellfish.csv
# - Total Fresh and Frozen Fish
# loss-adjusted-food-availability-clean/meat/total-fresh-and-frozen-fish-and-shellfish.csv
# - Canned Salmon
# loss-adjusted-food-availability-clean/meat/canned-salmon.csv
# - Canned Sardines
# loss-adjusted-food-availability-clean/meat/canned-sardines.csv
# - Canned Tuna
# loss-adjusted-food-availability-clean/meat/canned-tuna.csv
# - Canned shellfish
# loss-adjusted-food-availability-clean/meat/canned-shellfish.csv
# - Other canned fish
# loss-adjusted-food-availability-clean/meat/other-canned-fish.csv
# - Canned fish and shellfish
# loss-adjusted-food-availability-clean/meat/total-canned-fish-and-shellfish.csv
# - Cured fish
# loss-adjusted-food-availability-clean/meat/cured-fish.csv
# - Total fish and shellfish
# loss-adjusted-food-availability-clean/meat/total-fish-and-shellfish.csv
# - Eggs
# loss-adjusted-food-availability-clean/meat/eggs.csv
# - Peanuts
# loss-adjusted-food-availability-clean/meat/peanuts.csv
# - Almonds
# loss-adjusted-food-availability-clean/meat/almonds.csv
# - Hazelnuts
# loss-adjusted-food-availability-clean/meat/hazelnuts-(filberts).csv
# - Pecans
# loss-adjusted-food-availability-clean/meat/pecans.csv
# - Walnuts
# loss-adjusted-food-availability-clean/meat/walnuts.csv
# - Macadamia
# loss-adjusted-food-availability-clean/meat/macadamia-nuts.csv
# - Pistachios
# loss-adjusted-food-availability-clean/meat/pistachio-nuts.csv
# - Other tree nuts
# loss-adjusted-food-availability-clean/meat/other-tree-nuts.csv
# - Total tree nuts
# loss-adjusted-food-availability-clean/meat/total-tree-nuts.csv
# - Coconut
# loss-adjusted-food-availability-clean/meat/coconut.csv
# - Total meat fish eggs nuts group
# loss-adjusted-food-availability-clean/meat/total-meat,-fish,-eggs,-and-nuts.csv
# loss-adjusted-food-availability-clean/sugar
# - Cane and beet sugar
# loss-adjusted-food-availability-clean/sugar/refined-cane-and-beet-sugar.csv
# - Edible syrups
# loss-adjusted-food-availability-clean/sugar/edible-syrups.csv
# - Honey
# loss-adjusted-food-availability-clean/sugar/honey.csv
# - Total honey and syrup
# loss-adjusted-food-availability-clean/sugar/honey-and-edible-syrups.csv
# - High fructose corn syrup
# loss-adjusted-food-availability-clean/sugar/high-fructose-corn-syrup-(hfcs).csv
# - Glucose
# loss-adjusted-food-availability-clean/sugar/glucose.csv
# - Dextrose
# loss-adjusted-food-availability-clean/sugar/dextrose.csv
# - Corn sweeteners
# loss-adjusted-food-availability-clean/sugar/corn-sweeteners.csv
# - Caloric sweeteners
# loss-adjusted-food-availability-clean/sugar/caloric-sweeteners.csv
# loss-adjusted-food-availability-clean/dairy
# - Plain whole milk
# loss-adjusted-food-availability-clean/dairy/plain-whole-milk.csv
# - 2 percent milk
# loss-adjusted-food-availability-clean/dairy/plain-2-percent-milk.csv
# - 1 percent milk
# loss-adjusted-food-availability-clean/dairy/plain-1-percent-milk.csv
# - Skim milk
# loss-adjusted-food-availability-clean/dairy/skim-milk.csv
# - All plain milk
# loss-adjusted-food-availability-clean/dairy/all-plain-milk.csv
# - Whole flavored milk
# loss-adjusted-food-availability-clean/dairy/whole-flavored-milk.csv
# - Lower fat flavored milk
# loss-adjusted-food-availability-clean/dairy/flavored-lower-fat-milk.csv
# - All flavored milk
# loss-adjusted-food-availability-clean/dairy/all-flavored-milk.csv
# - Buttermilk
# loss-adjusted-food-availability-clean/dairy/buttermilk.csv
# - Eggnog
# loss-adjusted-food-availability-clean/dairy/dairy-share-of-eggnog.csv
# - Miscellaneous fluid milk
# loss-adjusted-food-availability-clean/dairy/miscellaneous-milk.csv
# - All beverage milks
# loss-adjusted-food-availability-clean/dairy/all-beverage-milks.csv
# - Yogurt
# loss-adjusted-food-availability-clean/dairy/yogurt.csv
# - Cheddar cheese
# loss-adjusted-food-availability-clean/dairy/cheddar-cheese.csv
# - Other American cheese
# loss-adjusted-food-availability-clean/dairy/other-american-cheese.csv
# - All American cheese
# loss-adjusted-food-availability-clean/dairy/all-american-cheese.csv
# - Provolone cheese
# loss-adjusted-food-availability-clean/dairy/provolone-cheese.csv
# - Romano cheese
# loss-adjusted-food-availability-clean/dairy/romano-cheese.csv
# - Parmesan cheese
# loss-adjusted-food-availability-clean/dairy/parmesan-cheese.csv
# - Mozarella cheese
# loss-adjusted-food-availability-clean/dairy/mozarella-cheese.csv
# - Ricotta cheese
# loss-adjusted-food-availability-clean/dairy/ricotta-cheese.csv
# - Other Italian cheese
# loss-adjusted-food-availability-clean/dairy/other-italian-cheese.csv
# - All Italian cheese
# loss-adjusted-food-availability-clean/dairy/all-italian-cheese.csv
# - Swiss cheese
# loss-adjusted-food-availability-clean/dairy/swiss-cheese.csv
# - Brick cheese
# loss-adjusted-food-availability-clean/dairy/brick-cheese.csv
# - Muenster cheese
# loss-adjusted-food-availability-clean/dairy/muenster-cheese.csv
# - Blue cheese
# loss-adjusted-food-availability-clean/dairy/blue-cheese.csv
# - Other miscellaneous cheese
# loss-adjusted-food-availability-clean/dairy/other-miscellaneous-cheese.csv
# - Total miscellaneous cheese
# loss-adjusted-food-availability-clean/dairy/all-miscellaneous-cheese.csv
# - Total cheese
# loss-adjusted-food-availability-clean/dairy/all-cheese.csv
# - Regular cottage cheese
# loss-adjusted-food-availability-clean/dairy/regular-cottage-cheese.csv
# - Lowfat cottage cheese
# loss-adjusted-food-availability-clean/dairy/lowfat-cottage-cheese.csv
# - Total cottage cheese
# loss-adjusted-food-availability-clean/dairy/total-cottage-cheese.csv
# - Regular ice cream
# loss-adjusted-food-availability-clean/dairy/regular-ice-cream.csv
# - Lowfat and nonfat ice cream
# loss-adjusted-food-availability-clean/dairy/lowfat-and-nonfat-ice-cream.csv
# - Other frozen
# loss-adjusted-food-availability-clean/dairy/frozen-yogurt,-sherbet,-and-other-miscellaneous-frozen-products.csv
# - Frozen dairy products
# loss-adjusted-food-availability-clean/dairy/total-frozen-dairy-products.csv
# - Evap cond canned whole milk
# loss-adjusted-food-availability-clean/dairy/evaporated-and-condensed-canned-whole-milk.csv
# - Evap cond bulk whole milk
# loss-adjusted-food-availability-clean/dairy/evaporated-and-condensed-bulk-whole-milk.csv
# - Evap cond skim milk
# loss-adjusted-food-availability-clean/dairy/evaporated-and-condensed-bulk-and-canned-skim-milk.csv
# - All evaporated condensed milk
# loss-adjusted-food-availability-clean/dairy/total-evaporated-and-condensed-milk.csv
# - Dry whole milk
# loss-adjusted-food-availability-clean/dairy/dry-whole-milk.csv
# - Nonfat dry milk
# loss-adjusted-food-availability-clean/dairy/nonfat-dry-milk.csv
# - Dry buttermilk
# loss-adjusted-food-availability-clean/dairy/dry-buttermilk.csv
# - Dry milk products
# loss-adjusted-food-availability-clean/dairy/all-dry-milk-products.csv
# - Half and half
# loss-adjusted-food-availability-clean/dairy/dairy-share-of-half-and-half.csv
# - Total dairy products
# loss-adjusted-food-availability-clean/dairy/all-dairy-products.csv
# loss-adjusted-food-availability-clean/fat
# - Butter
# loss-adjusted-food-availability-clean/fat/butter.csv
# - Margarine
# loss-adjusted-food-availability-clean/fat/margarine.csv
# - Lard
# loss-adjusted-food-availability-clean/fat/lard.csv
# - Edible beef tallow
# loss-adjusted-food-availability-clean/fat/edible-beef-tallow.csv
# - Shortening
# loss-adjusted-food-availability-clean/fat/shortening.csv
# - Salad and cooking oils
# loss-adjusted-food-availability-clean/fat/salad-and-cooking-oils.csv
# - Other edible fats and oils
# loss-adjusted-food-availability-clean/fat/other-edible-fats-and-oils.csv
# - Added fats
# loss-adjusted-food-availability-clean/fat/added-fats-and-oils.csv
# - Half and half
# loss-adjusted-food-availability-clean/fat/fat-share-of-half-and-half.csv
# - Light cream
# loss-adjusted-food-availability-clean/fat/light-cream.csv
# - Heavy cream
# loss-adjusted-food-availability-clean/fat/heavy-cream.csv
# - Sour cream
# loss-adjusted-food-availability-clean/fat/sour-cream.csv
# - Cream cheese
# loss-adjusted-food-availability-clean/fat/cream-cheese.csv
# - Eggnog
# loss-adjusted-food-availability-clean/fat/fat-share-of-egg-nog.csv
# - Dairy fats
# loss-adjusted-food-availability-clean/fat/dairy-fats.csv
# - Total fats
# loss-adjusted-food-availability-clean/fat/total-fats.csv
# loss-adjusted-food-availability-clean/veg
# - Fresh artichokes
# loss-adjusted-food-availability-clean/veg/fresh-artichokes.csv
# - Fresh asparagus
# loss-adjusted-food-availability-clean/veg/fresh-asparagus.csv
# - Fresh bell peppers
# loss-adjusted-food-availability-clean/veg/fresh-bell-peppers.csv
# - Fresh broccoli
# loss-adjusted-food-availability-clean/veg/fresh-broccoli.csv
# - Fresh brussels sprouts
# loss-adjusted-food-availability-clean/veg/fresh-brussels-sprouts.csv
# - Fresh cabbage
# loss-adjusted-food-availability-clean/veg/fresh-cabbage.csv
# - Fresh carrots
# loss-adjusted-food-availability-clean/veg/fresh-carrots.csv
# - Fresh cauliflower
# loss-adjusted-food-availability-clean/veg/fresh-cauliflower.csv
# - Fresh celery
# loss-adjusted-food-availability-clean/veg/fresh-celery.csv
# - Fresh collard greens
# loss-adjusted-food-availability-clean/veg/fresh-collard-greens.csv
# - Fresh sweet corn
# loss-adjusted-food-availability-clean/veg/fresh-sweet-corn.csv
# - Fresh cucumbers
# loss-adjusted-food-availability-clean/veg/fresh-cucumbers.csv
# - Fresh eggplant
# loss-adjusted-food-availability-clean/veg/fresh-eggplant.csv
# - Fresh escarole
# loss-adjusted-food-availability-clean/veg/fresh-escarole-endive.csv
# - Fresh garlic
# loss-adjusted-food-availability-clean/veg/fresh-garlic.csv
# - Fresh kale
# loss-adjusted-food-availability-clean/veg/fresh-kale.csv
# - Fresh head lettuce
# loss-adjusted-food-availability-clean/veg/fresh-head-lettuce.csv
# - Fresh leaf lettuce
# loss-adjusted-food-availability-clean/veg/fresh-romaine-and-leaf-lettuce.csv
# - Fresh lima beans
# loss-adjusted-food-availability-clean/veg/fresh-lima-beans.csv
# - Fresh mushrooms
# loss-adjusted-food-availability-clean/veg/fresh-mushrooms.csv
# - Fresh mustard greens
# loss-adjusted-food-availability-clean/veg/fresh-mustard-greens.csv
# - Fresh okra
# loss-adjusted-food-availability-clean/veg/fresh-okra.csv
# - Fresh onions
# loss-adjusted-food-availability-clean/veg/fresh-onions.csv
# - Fresh potatoes
# loss-adjusted-food-availability-clean/veg/fresh-potatoes.csv
# - Fresh pumpkin
# loss-adjusted-food-availability-clean/veg/fresh-pumpkin.csv
# - Fresh radishes
# loss-adjusted-food-availability-clean/veg/fresh-radishes.csv
# - Fresh snap beans
# loss-adjusted-food-availability-clean/veg/fresh-snap-beans.csv
# - Fresh spinach
# loss-adjusted-food-availability-clean/veg/fresh-spinach.csv
# - Fresh squash
# loss-adjusted-food-availability-clean/veg/fresh-squash.csv
# - Fresh sweetpotatoes
# loss-adjusted-food-availability-clean/veg/fresh-sweet-potatoes.csv
# - Fresh tomatoes
# loss-adjusted-food-availability-clean/veg/fresh-tomatoes.csv
# - Fresh turnip greens
# loss-adjusted-food-availability-clean/veg/fresh-turnip-greens.csv
# - Fresh vegetables
# loss-adjusted-food-availability-clean/veg/fresh-vegetables.csv
# - Canned asparagus
# loss-adjusted-food-availability-clean/veg/canned-asparagus.csv
# - Canned snap beans
# loss-adjusted-food-availability-clean/veg/canned-snap-beans.csv
# - Canned cabbage
# loss-adjusted-food-availability-clean/veg/canned-cabbage-(sauerkraut).csv
# - Canned carrots
# loss-adjusted-food-availability-clean/veg/canned-carrots.csv
# - Canned sweet corn
# loss-adjusted-food-availability-clean/veg/canned-sweet-corn.csv
# - Canned cucumbers
# loss-adjusted-food-availability-clean/veg/canned-cucumbers-(pickles).csv
# - Canned green peas
# loss-adjusted-food-availability-clean/veg/canned-green-peas.csv
# - Canned mushrooms
# loss-adjusted-food-availability-clean/veg/canned-mushrooms.csv
# - Canned chile peppers
# loss-adjusted-food-availability-clean/veg/canned-chile-peppers.csv
# - Canned potatoes
# loss-adjusted-food-availability-clean/veg/canned-potatoes.csv
# - Canned tomatoes
# loss-adjusted-food-availability-clean/veg/canned-tomatoes.csv
# - Other canned vegetables
# loss-adjusted-food-availability-clean/veg/other-canned-vegetables.csv
# - Canned vegetables
# loss-adjusted-food-availability-clean/veg/canned-vegetables.csv
# - Frozen asparagus
# loss-adjusted-food-availability-clean/veg/frozen-asparagus.csv
# - Frozen snap beans
# loss-adjusted-food-availability-clean/veg/frozen-snap-beans.csv
# - Frozen broccoli
# loss-adjusted-food-availability-clean/veg/frozen-broccoli.csv
# - Frozen carrots
# loss-adjusted-food-availability-clean/veg/frozen-carrots.csv
# - Frozen cauliflower
# loss-adjusted-food-availability-clean/veg/frozen-cauliflower.csv
# - Frozen sweet corn
# loss-adjusted-food-availability-clean/veg/frozen-sweet-corn.csv
# - Frozen green peas
# loss-adjusted-food-availability-clean/veg/frozen-green-peas.csv
# - Frozen lima beans
# loss-adjusted-food-availability-clean/veg/frozen-green-lima-beans.csv
# - Frozen potatoes
# loss-adjusted-food-availability-clean/veg/frozen-potatoes.csv
# - Frozen spinach
# loss-adjusted-food-availability-clean/veg/frozen-spinach.csv
# - Misc frozen vegetables
# loss-adjusted-food-availability-clean/veg/miscellaneous-frozen-vegetables.csv
# - Frozen vegetables
# loss-adjusted-food-availability-clean/veg/frozen-vegetables.csv
# - Dehydrated onions
# loss-adjusted-food-availability-clean/veg/dehydrated-onions.csv
# - Dehydrated potatoes
# loss-adjusted-food-availability-clean/veg/dehydrated-potatoes.csv
# - Potato chips
# loss-adjusted-food-availability-clean/veg/potato-chips-and-shoestring-potatoes.csv
# - Other processed vegetables
# loss-adjusted-food-availability-clean/veg/processed-and-dehydrated-vegetables.csv
# - Dry Peas and lentils
# loss-adjusted-food-availability-clean/veg/dry-peas-and-lentils.csv
# - Dry black beans
# loss-adjusted-food-availability-clean/veg/dry-black-beans.csv
# - Dry great northern beans
# loss-adjusted-food-availability-clean/veg/dry-great-northern-beans.csv
# - Dry lima beans
# loss-adjusted-food-availability-clean/veg/dry-lima-beans.csv
# - Dry navy beans
# loss-adjusted-food-availability-clean/veg/dry-navy-beans.csv
# - Dry pinto beans
# loss-adjusted-food-availability-clean/veg/dry-pinto-beans.csv
# - Dry red kidney beans
# loss-adjusted-food-availability-clean/veg/dry-red-kidney-beans.csv
# - Other dry beans
# loss-adjusted-food-availability-clean/veg/other-dry-beans.csv
# - Dry edible beans
# loss-adjusted-food-availability-clean/veg/dry-edible-beans.csv
# - Legumes
# loss-adjusted-food-availability-clean/veg/legumes.csv
# - Vegetables
# loss-adjusted-food-availability-clean/veg/vegetables.csv
# loss-adjusted-food-availability-clean/fruit
# - Fresh oranges
# loss-adjusted-food-availability-clean/fruit/fresh-oranges-and-temples.csv
# - Fresh tangerines
# loss-adjusted-food-availability-clean/fruit/fresh-tangerines-and-tangelos.csv
# - Fresh grapefruit
# loss-adjusted-food-availability-clean/fruit/fresh-grapefruit.csv
# - Fresh lemons
# loss-adjusted-food-availability-clean/fruit/fresh-lemons.csv
# - Fresh limes
# loss-adjusted-food-availability-clean/fruit/fresh-limes.csv
# - Fresh citrus
# loss-adjusted-food-availability-clean/fruit/fresh-citrus-fruit.csv
# - Fresh apples
# loss-adjusted-food-availability-clean/fruit/fresh-apples.csv
# - Fresh apricots
# loss-adjusted-food-availability-clean/fruit/fresh-apricots.csv
# - Fresh avocados
# loss-adjusted-food-availability-clean/fruit/fresh-avocados.csv
# - Fresh bananas
# loss-adjusted-food-availability-clean/fruit/fresh-bananas.csv
# - Fresh blueberries
# loss-adjusted-food-availability-clean/fruit/fresh-blueberries.csv
# - Fresh cantaloupe
# loss-adjusted-food-availability-clean/fruit/fresh-cantaloupe.csv
# - Fresh cherries
# loss-adjusted-food-availability-clean/fruit/fresh-cherries.csv
# - Fresh cranberries
# loss-adjusted-food-availability-clean/fruit/fresh-cranberries.csv
# - Fresh grapes
# loss-adjusted-food-availability-clean/fruit/fresh-grapes.csv
# - Fresh honeydew
# loss-adjusted-food-availability-clean/fruit/fresh-honeydew-melons.csv
# - Fresh kiwi
# loss-adjusted-food-availability-clean/fruit/fresh-kiwifruit.csv
# - Fresh mangoes
# loss-adjusted-food-availability-clean/fruit/fresh-mangoes.csv
# - Fresh papaya
# loss-adjusted-food-availability-clean/fruit/fresh-papaya.csv
# - Fresh peaches
# loss-adjusted-food-availability-clean/fruit/fresh-peaches-and-nectarines.csv
# - Fresh pears
# loss-adjusted-food-availability-clean/fruit/fresh-pears.csv
# - Fresh pineapple
# loss-adjusted-food-availability-clean/fruit/fresh-pineapple.csv
# - Fresh plums
# loss-adjusted-food-availability-clean/fruit/fresh-plums-and-prunes.csv
# - Fresh raspberries
# loss-adjusted-food-availability-clean/fruit/fresh-raspberries.csv
# - Fresh strawberries
# loss-adjusted-food-availability-clean/fruit/fresh-strawberries.csv
# - Fresh watermelon
# loss-adjusted-food-availability-clean/fruit/fresh-watermelon.csv
# - Fresh noncitrus
# loss-adjusted-food-availability-clean/fruit/fresh-noncitrus-fruit.csv
# - Fresh fruit
# loss-adjusted-food-availability-clean/fruit/fresh-fruit.csv
# - Canned apples
# loss-adjusted-food-availability-clean/fruit/canned-apples-and-applesauce.csv
# - Canned apricots
# loss-adjusted-food-availability-clean/fruit/canned-apricots.csv
# - Canned sweet cherries
# loss-adjusted-food-availability-clean/fruit/canned-sweet-cherries.csv
# - Canned tart cherries
# loss-adjusted-food-availability-clean/fruit/canned-tart-cherries.csv
# - Canned peaches
# loss-adjusted-food-availability-clean/fruit/canned-peaches.csv
# - Canned pears
# loss-adjusted-food-availability-clean/fruit/canned-pears.csv
# - Canned pineapple
# loss-adjusted-food-availability-clean/fruit/canned-pineapples.csv
# - Canned plums
# loss-adjusted-food-availability-clean/fruit/canned-plums-and-prunes.csv
# - Canned olives
# loss-adjusted-food-availability-clean/fruit/canned-olives.csv
# - Canned fruit
# loss-adjusted-food-availability-clean/fruit/canned-fruit.csv
# - Frozen blackberries
# loss-adjusted-food-availability-clean/fruit/frozen-blackberries.csv
# - Frozen blueberries
# loss-adjusted-food-availability-clean/fruit/frozen-blueberries.csv
# - Frozen raspberries
# loss-adjusted-food-availability-clean/fruit/frozen-raspberries.csv
# - Frozen strawberries
# loss-adjusted-food-availability-clean/fruit/frozen-strawberries.csv
# - Frozen other berries
# loss-adjusted-food-availability-clean/fruit/other-frozen-berries.csv
# - Frozen berries
# loss-adjusted-food-availability-clean/fruit/frozen-berries.csv
# - Frozen apples
# loss-adjusted-food-availability-clean/fruit/frozen-apples.csv
# - Frozen apricots
# loss-adjusted-food-availability-clean/fruit/frozen-apricots.csv
# - Frozen sweet cherries
# loss-adjusted-food-availability-clean/fruit/frozen-sweet-cherries.csv
# - Frozen tart cherries
# loss-adjusted-food-availability-clean/fruit/frozen-tart-cherries.csv
# - Frozen peaches
# loss-adjusted-food-availability-clean/fruit/frozen-peaches.csv
# - Frozen plums
# loss-adjusted-food-availability-clean/fruit/frozen-plums-and-prunes.csv
# - Frozen other fruit
# loss-adjusted-food-availability-clean/fruit/other-frozen-fruit.csv
# - Frozen fruit
# loss-adjusted-food-availability-clean/fruit/frozen-fruit.csv
# - Dried apples
# loss-adjusted-food-availability-clean/fruit/dried-apples.csv
# - Dried apricots
# loss-adjusted-food-availability-clean/fruit/dried-apricots.csv
# - Dried dates
# loss-adjusted-food-availability-clean/fruit/dried-dates.csv
# - Dried figs
# loss-adjusted-food-availability-clean/fruit/dried-figs.csv
# - Dried peaches
# loss-adjusted-food-availability-clean/fruit/dried-peaches.csv
# - Dried pears
# loss-adjusted-food-availability-clean/fruit/dried-pears.csv
# - Dried plums
# loss-adjusted-food-availability-clean/fruit/dried-plums-(prunes).csv
# - Raisins
# loss-adjusted-food-availability-clean/fruit/raisins.csv
# - Dried fruit
# loss-adjusted-food-availability-clean/fruit/dried-fruit.csv
# - Grapefruit juice
# loss-adjusted-food-availability-clean/fruit/grapefruit-juice.csv
# - Lemon juice
# loss-adjusted-food-availability-clean/fruit/lemon-juice.csv
# - Lime juice
# loss-adjusted-food-availability-clean/fruit/lime-juice.csv
# - Orange juice
# loss-adjusted-food-availability-clean/fruit/orange,-temple,-tangerine-and-tangelo-juice.csv
# - Citrus juice
# loss-adjusted-food-availability-clean/fruit/citrus-juice.csv
# - Apple juice
# loss-adjusted-food-availability-clean/fruit/apple-juice.csv
# - Cranberry juice
# loss-adjusted-food-availability-clean/fruit/cranberry-juice.csv
# - Grape juice
# loss-adjusted-food-availability-clean/fruit/grape-juice.csv
# - Pineapple juice
# loss-adjusted-food-availability-clean/fruit/pineapple-juice.csv
# - Prune juice
# loss-adjusted-food-availability-clean/fruit/prune-juice.csv
# - Noncitrus juice
# loss-adjusted-food-availability-clean/fruit/noncitrus-juice.csv
# - Juice
# loss-adjusted-food-availability-clean/fruit/fruit-juice.csv
# - Fruit
# loss-adjusted-food-availability-clean/fruit/fruit.csv
# loss-adjusted-food-availability-clean/grain
# - White and whole wheat flour
# loss-adjusted-food-availability-clean/grain/white-and-whole-wheat-flour.csv
# - Durum flour
# loss-adjusted-food-availability-clean/grain/durum-flour.csv
# - Wheat flour
# loss-adjusted-food-availability-clean/grain/wheat-flour.csv
# - Total wheat flour
# loss-adjusted-food-availability-clean/grain/wheat-flour.csv
# - Rye flour
# loss-adjusted-food-availability-clean/grain/rye-flour.csv
# - Rice
# loss-adjusted-food-availability-clean/grain/rice.csv
# - Corn flour and meal
# loss-adjusted-food-availability-clean/grain/corn-flour-and-meal.csv
# - Corn hominy and grits
# loss-adjusted-food-availability-clean/grain/corn-hominy-and-grits.csv
# - Corn starch
# loss-adjusted-food-availability-clean/grain/corn-starch.csv
# - Total Corn Products
# loss-adjusted-food-availability-clean/grain/corn.csv
# - Oat products
# loss-adjusted-food-availability-clean/grain/oat-products.csv
# - Barley products
# loss-adjusted-food-availability-clean/grain/barley-products.csv
# - Total grains
# loss-adjusted-food-availability-clean/grain/grains.csv

# %%
dirname = 'food'
file = "asdf.csv"

path = os.path.join(dirname, file)
path
# Out:
# 'food/asdf.csv'
